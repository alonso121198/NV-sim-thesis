# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os
from lmfit.models import LorentzianModel, QuadraticModel # Para el ajuste cuadrático

import scienceplots # Para obtener graficos de alta calidad
plt.style.use(['science','notebook','grid','std-colors'])
#plt.style.use(['nature','no-latex'])

os.getcwd()
# Out:
# 'C:\\Users\\JAAL_\\Documentos\\Academico\\Tesis\\Redacción-tesis\\Imagenes-de-la-tesis-en-orden\\Figuras-oficiales-enumerados-hechas\\Figuras-capitulo-3\\super_fig_5\\Reproduciendo_tettiene'

# %% [markdown]
# ## Funciones a definir

# %%
def dividir_matriz_en_submatrices(matriz, m):
    n1 = matriz.shape[0]
    n2 = matriz.shape[1]
    if n1 % m != 0 or n2 % m:
        print(f"dimensión filas de la matriz {n1}")
        print(f"dimensión columna de la matriz {n2}")
        print(f"dimensión de la submatriz {m}")
        raise ValueError("El tamaño de la matriz no es divisible por el tamaño de las submatrices.")
    
    # Crear una lista de submatrices
    submatrices = []
    
    for i in range(0, n1, m):
        fila_submatrices = []
        for j in range(0, n2, m):
            submatriz = matriz[i:i+m, j:j+m]
            fila_submatrices.append(submatriz)
        submatrices.append(fila_submatrices)
    
    return np.array(submatrices)

def add_peak(prefix, center, amplitude=6, sigma=3):
    peak = LorentzianModel(prefix=prefix)
    pars = peak.make_params()
    pars[prefix + 'center'].set(center)
    pars[prefix + 'amplitude'].set(amplitude)
    pars[prefix + 'sigma'].set(sigma, min=0)
    return peak, pars

# %%
# Para regresar a la carpeta
os.chdir('C:\\Users\\JAAL_\\Documentos\\Academico\\Tesis\\Redacción-tesis\\Imagenes-de-la-tesis-en-orden\\Figuras-oficiales-enumerados-hechas\\Figuras-capitulo-3\\super_fig_5\\Reproduciendo_tettiene')

# %% [markdown]
# # Explicación de la data por Tietenne para step 0
#
# - Esta carpeta contiene los datos ODMR crudos en dos archivos binarios, uno para los datos en presencia de una corriente I = 4 mA **('ODMR_data_with_current')**, y el otro para los datos sin corriente aplicada **('ODMR_data_without_current')**.
#
# - Cada archivo contiene la intensidad de PL cruda (en cuentas) para cada píxel de la cámara y para cada frecuencia de microondas del escaneo, escrita en una sola columna.
#
# - Cada fotograma de la cámara tiene 1024 x 1024 píxeles con un tamaño físico de píxel de 108 nm x 108 nm, y hay 281 frecuencias de microondas.
# - Además, para cada frecuencia se toman 2 fotogramas (uno con microondas encendidas y otro con microondas apagadas) para permitir la eliminación de fluctuaciones de modo común. Esto da un total de 1024 x 1024 x 281 x 2 valores de intensidad de PL.
#
# - La variable 'PL_norm' es una matriz de 1024 x 1024 x 281 que representa los mapas de intensidad de PL normalizados (microondas encendidas/apagadas) (1024 x 1024 píxeles) para cada una de las 281 frecuencias de microondas. La variable 'freq' es el vector de frecuencia de microondas (expresado en MHz) correspondiente a este conjunto de datos.
#
# - En esta carpeta también hay imágenes .png que muestran el mapa PL para una frecuencia determinada, así como el espectro ODMR resumido en toda la imagen.

# %% [markdown]
# ## Abrimos la data y transformamos a una matriz adecuada

# %%
# Carpeta donde esta la data para extraerla
os.chdir('C:/Users/JAAL_/Documentos/ODMR-jupyter-calculo-magnetometria/Datos-tiettene/datos/Step 0 - Raw ODMR data')

file_name = "ODMR_data_with_current" 
# file_name = "ODMR_data_without_current" / Extraemos datos sin corriente

# Abre el archivo
with open(file_name, 'rb') as fileID:
    # Lee el contenido del archivo como números de precisión simple (float32)
    data = fileID.read()
    # Convertir los datos leídos en un array numpy de tipo float32
    temp = np.frombuffer(data, dtype=np.float32)
    
# Descartar los dos primeros elementos
temp = temp[2:]
# display(temp.shape)

# Reshape del array según las dimensiones especificadas
PL_raw = np.reshape(temp, (2 * 281, 1024, 1024))

# Extraer PL_MW_on y PL_MW_off
# En numpy, el slicing (corte de segmentos del array) se realiza utilizando la notación [inicio:fin:paso] 
# Ojo con esto que es demasiado util este slicing
PL_MW_on = PL_raw[ 0:2*281:2,:,:]
PL_MW_off = PL_raw[1:2*281:2,:,:]

# Calcular PL_norm
PL_norm = PL_MW_on / PL_MW_off
PL_norm = PL_norm/PL_norm.max()

# Definir el vector de frecuencia
freq = np.arange(2730, 3011)

# Imprimir los resultados para verificar
# print("PL_norm shape:", PL_norm.shape)
# print("freq shape", freq.shape)
# print("freq:", freq)

# %% [markdown]
# ## Graficamos la imagen para una frecuencia

# %%
# Para regresar a la carpeta
os.chdir('C:/Users/JAAL_/Documentos/Academico/Tesis/Redacción-tesis/Imagenes-de-la-tesis-en-orden/Figuras-oficiales-enumerados-hechas/Figuras-capitulo-3/super_fig_5/Reproduciendo_tettiene')

# %%
import matplotlib.pyplot as plt
import numpy as np
fluorescencia = PL_MW_on[10,:,:]

# Mostrar la imagen usando matplotlib
plt.imshow(fluorescencia, cmap='gray')  # 'gray' para imágenes en escala de grises
plt.colorbar(label='Intensidad de Gris')  # Añadir la barra de colores con etiqueta
plt.axis('on')  # Desactivar los ejes

plt.savefig('./Con_corriente_guardados/Resultados/Fluorescencia_imagen')
plt.show()

# %% [markdown]
# ## Graficamos el ODMR

# %%
ODMR = np.sum(PL_norm, axis=(1,2))
ODMR = ODMR/ODMR.max()
plt.plot(freq,ODMR,'o-')
plt.savefig('./Con_corriente_guardados/Resultados/ODMR-suma-espectro.png')
# Estructura de datos para guardar 
# (guarda como dos columna / 1 columna las frecuencia / 2 columna la fluorescencia normalizada ) )
A = np.column_stack((x1, Nnt))
np.save('./ODMR-con-corriente', np.array([freq,ODMR]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 plt.savefig('./Con_corriente_guardados/Resultados/ODMR-suma-espectro.png')
#       5 # Estructura de datos para guardar
#       6 # (guarda como dos columna / 1 columna las frecuencia / 2 columna la fluorescencia normalizada ) )
# ----> 7 A = np.column_stack((x1, Nnt))
#       8 np.save('./ODMR-con-corriente', np.array([freq,ODMR]))
#       9 plt.show()
#
# NameError: name 'x1' is not defined

# %% [markdown]
# # Explicación por Tietenne para step 1
#
# Esta carpeta contiene el resultado del ajuste de los datos ODMR sin procesar, es decir, la frecuencia, el contraste y el ancho de cada una de las 8 líneas de resonancia observadas en los espectros.
#
# Para obtener estos resultados, los datos ODMR sin procesar, es decir, matrices 2D de la intensidad PL para un rango de frecuencias de microondas, fueron rebinados utilizando 'imresize' en Matlab.
# Esto reduce el tamaño de la matriz de 1024 x 1024 a 256 x 256. El tamaño físico del píxel después de rebinado es de 432 nm x 432 nm.
# El espectro ODMR en cada píxel se ajustó a una suma de 8 funciones Lorentzianas con frecuencias, amplitud (contraste) y ancho libres.
#
# Hay tres subcarpetas diferentes en esta carpeta: una para frecuencia, una para contraste y una para ancho.
# En cada carpeta, hay 8 archivos de texto, uno para cada línea ODMR vista en los espectros.
# Están numerados del 1 al 8 en orden de frecuencia de resonancia creciente (es decir, 1 es la frecuencia más pequeña y 8 es la más grande).
#
# Cada archivo de texto (por ejemplo, 'freq_1.txt') contiene una matriz de 256 x 256 de la cantidad dada (por ejemplo, la frecuencia de la primera línea de resonancia).
# La matriz se puede importar y graficar directamente en Matlab utilizando 'imagesc' para obtener la imagen en el espacio real de esa cantidad.
#
# Además, como guía, en esta carpeta hay una imagen .png que muestra la proyección del campo magnético $B_{NV}$ a lo largo de cada eje NV, obtenida utilizando la fórmula aproximada:
# \begin{align*}
# B_{NV_1} &= \frac{\text{freq}_8 - \text{freq}_1}{2 \times 2.8 \, \text{MHz/G}} \\
# B_{NV_2} &= \frac{\text{freq}_7 - \text{freq}_2}{2 \times 2.8 \, \text{MHz/G}} \\
# B_{NV_3} &= \frac{\text{freq}_6 - \text{freq}_3}{2 \times 2.8 \, \text{MHz/G}} \\
# B_{NV_4} &= \frac{\text{freq}_5 - \text{freq}_4}{2 \times 2.8 \, \text{MHz/G}}
# \end{align*}
#
# Para referencia futura, los vectores unitarios que definen el eje de simetría de cada familia NV son los siguientes (fijados por el campo magnético externo):
#
#
# - frequencies 1 and 8 correspond to NV unit vector $\left[0,-\sqrt{\frac{2}{3}},-\sqrt{\frac{1}{3}}\right]$
# - frequencies 2 and 7 correspond to NV unit vector $\left[\sqrt{\frac{2}{3}},0,-\sqrt{\frac{1}{3}}\right]$
# - frequencies 3 and 6 correspond to NV unit vector $\left[-\sqrt{\frac{2}{3}},0,-\sqrt{\frac{1}{3}}\right]$
# - frequencies 4 and 5 correspond to NV unit vector $\left[0,\sqrt{\frac{2}{3}},-\sqrt{\frac{1}{3}}\right]$
#
# Estos vectores unitarios se definen en el marco del laboratorio xyz, donde en las imágenes 2D trazadas x es horizontal, y es vertical y z está fuera del plano.

# %% [markdown]
# ## Transformamos la matriz en submatrices

# %%
ODMR = [] # La lista supergrande 
m = 4 # m es la subdivisión de matrices cuadradas / con 16 demora mucho los algoritmos de más adelante /
for j in range(len(freq)):
    imag = PL_norm[j]
    # Convertimos la matriz en submatrices 
    submatriz_imag = dividir_matriz_en_submatrices(imag, m)
    ODMR.append(np.array(submatriz_imag))

ODMR1 = np.array(ODMR) # Es importante transformarlo a array

print("( frecuencia_j, submatriz_k, submatriz_l, elemento fila_l, elemento columna_n)")
display(ODMR1.shape)
# Out:
# ( frecuencia_j, submatriz_k, submatriz_l, elemento fila_l, elemento columna_n)
# (281, 256, 256, 4, 4)

# %%
# Hacemos una suma sobre las submatrices
print("( frecuencia_j, submatriz_k, submatriz_l)")
ODMR2 = np.sum(ODMR1, axis=(3,4))
display(ODMR2.shape)
# Out:
# ( frecuencia_j, submatriz_k, submatriz_l)
# (281, 256, 256)

# %%
fluorescencia = ODMR2[10,:,:]

# Mostrar la imagen usando matplotlib
plt.imshow(fluorescencia, cmap='gray')  # 'gray' para imágenes en escala de grises
plt.colorbar(label='Intensidad de Gris')  # Añadir la barra de colores con etiqueta
plt.axis('on')  # Desactivar los ejes
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Hallamos las frecuencias para un pixel particular

# %%
l,k = 1,1
ydat = np.array([ODMR2[i][l][k] for i in range(ODMR2.shape[0]) if True])
ydat = ydat/ydat.max()
xdat = freq
plt.plot(xdat,ydat)

# %%
model = QuadraticModel(prefix='bkg_')
params = model.make_params(a=0, b=0, c=0)

rough_peak_positions = (2760, 2800, 2837, 2860, 2880, 2920, 2950, 2970)
for i, cen in enumerate(rough_peak_positions):
    peak, pars = add_peak('lz%d_' % (i+1), cen)
    model = model + peak
    params.update(pars)

init = model.eval(params, x=xdat)
result = model.fit(ydat, params, x=xdat)
comps = result.eval_components()

# print(result.fit_report(min_correl=0.5))

plt.plot(xdat, ydat,'o', label='data')
plt.plot(xdat, result.best_fit, label='best fit')

for name, comp in comps.items():
    if name == 'bkg_':
        plt.plot(xdat,comps['bkg_'], label='bkg_')
    else:
        plt.plot(xdat, comp + 1, '--', label=name)
plt.legend(loc='upper right')

plt.savefig('./Con_corriente_guardados/Resultados/ODMR-pixel-particular')
plt.show()

# Acceder a los centros de lz1 y lz2
min1 = result.params['lz1_center'].value
min2 = result.params['lz2_center'].value
min3 = result.params['lz3_center'].value
min4 = result.params['lz4_center'].value
min5 = result.params['lz5_center'].value
min6 = result.params['lz6_center'].value
min7 = result.params['lz7_center'].value
min8 = result.params['lz8_center'].value
frecmin = np.array([min1,min2,min3,min4,min5,min6,min7,min8])

print(f"Los minimos son {frecmin}")
# Out:
# Los minimos son [2764.28166736 2797.9111417  2833.90191521 2864.98298346 2890.65314472
#  2919.78295671 2951.6376725  2979.22393891]

# %% [markdown]
# ## Hacemos la iteración sobre los pixeles

# %%
############### iteramos sobre los pixeles

min1, min2, min3, min4, min5, min6, min7, min8 = 2760,2800, 2837, 2860, 2880, 2920, 2950, 2970
rough_peak_positions = (min1, min2, min3, min4, min5, min6, min7, min8) 

filas = []
for j in range(ODMR2.shape[1]):
    columna = []
    for k in range(ODMR2.shape[2]): 
        for i in range(ODMR2.shape[0]):
            ydat = np.array([ODMR2[i][j][k] for i in range(ODMR2.shape[0]) if True])
    
        ydat = ydat/ydat.max()
        xdat = freq
        
        model = QuadraticModel(prefix='bkg_')
        params = model.make_params(a=0, b=0, c=0)
        
        rough_peak_positions = (min1, min2, min3, min4, min5, min6, min7, min8)
        for i, cen in enumerate(rough_peak_positions):
            peak, pars = add_peak('lz%d_' % (i+1), cen)
            model = model + peak
            params.update(pars)
            
        init = model.eval(params, x=xdat)
        result = model.fit(ydat, params, x=xdat)
        comps = result.eval_components()
        
        # Acceder a los centros de lz1 y lz2
        valores = [] # valores de frecuencia 
        min1 = result.params['lz1_center'].value
        valores.append(min1)
        min2 = result.params['lz2_center'].value
        valores.append(min2)
        min3 = result.params['lz3_center'].value
        valores.append(min3)
        min4 = result.params['lz4_center'].value
        valores.append(min4)
        min5 = result.params['lz5_center'].value
        valores.append(min5)
        min6 = result.params['lz6_center'].value
        valores.append(min6)
        min7 = result.params['lz7_center'].value
        valores.append(min7)
        min8 = result.params['lz8_center'].value
        valores.append(min8)
        
        columna.append(np.array(valores))
    print(j) # No borres esto, confia en lo que te digo
        
    filas.append(np.array(columna))

frecuencias = np.array(filas)
frecuencias.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 26
#      23     params.update(pars)
#      25 init = model.eval(params, x=xdat)
# ---> 26 result = model.fit(ydat, params, x=xdat)
#      27 comps = result.eval_components()
#      29 # Acceder a los centros de lz1 y lz2
#
# File ~\anaconda3\Lib\site-packages\lmfit\model.py:1177, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, coerce_farray, **kwargs)
#    1171     fit_kws = {}
#    1173 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#    1174                      scale_covar=scale_covar, fcn_kws=kwargs,
#    1175                      nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1176                      max_nfev=max_nfev, **fit_kws)
# -> 1177 output.fit(data=data, weights=weights)
#    1178 output.components = self.components
#    1179 return output
#
# File ~\anaconda3\Lib\site-packages\lmfit\model.py:1570, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1568 self.userkws.update(kwargs)
#    1569 self.init_fit = self.model.eval(params=self.init_params, **self.userkws)
# -> 1570 _ret = self.minimize(method=self.method, params=self.init_params)
#    1571 self.model.post_fit(_ret)
#    1572 _ret.params.create_uvars(covar=_ret.covar)
#
# File ~\anaconda3\Lib\site-packages\lmfit\minimizer.py:2330, in Minimizer.minimize(self, method, params, **kws)
#    2327         if (key.lower().startswith(user_method) or
#    2328                 val.lower().startswith(user_method)):
#    2329             kwargs['method'] = val
# -> 2330 return function(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\lmfit\minimizer.py:1693, in Minimizer.leastsq(self, params, max_nfev, **kws)
#    1691     result.covar = self._int2ext_cov_x(_cov, _best)
#    1692     # calculate parameter uncertainties and correlations
# -> 1693     self._calculate_uncertainties_correlations()
#    1694 else:
#    1695     result.message = f'{result.message} Could not estimate error-bars.'
#
# File ~\anaconda3\Lib\site-packages\lmfit\minimizer.py:813, in Minimizer._calculate_uncertainties_correlations(self)
#     811         self.result.errorbars = False
#     812 if self.result.errorbars:
# --> 813     self.result.uvars = self.result.params.create_uvars(covar=self.result.covar)
#
# File ~\anaconda3\Lib\site-packages\lmfit\parameter.py:539, in Parameters.create_uvars(self, covar)
#     537 if getattr(par, '_expr_ast', None) is not None:
#     538     try:
# --> 539         uval = wrap_ueval(*corr_uvars, obj=par,
#     540                           pars=self, names=vnames)
#     541         par.stderr = uval.std_dev
#     542         uvars[par.name] = uval
#
# File ~\anaconda3\Lib\site-packages\uncertainties\core.py:641, in wrap.<locals>.f_with_affine_output(*args, **kwargs)
#     636 linear_part = []
#     638 for pos in pos_w_uncert:
#     639     linear_part.append((
#     640         # Coefficient:
# --> 641         derivatives_args_index[pos](*args_values, **kwargs),
#     642         # Linear part of the AffineScalarFunc expression:
#     643         args[pos]._linear_part))
#     645 for name in names_w_uncert:
#     646
#     647     # Optimization: caching of the automatic numerical
#    (...)
#     650     # function is called repeatedly with the same keyword
#     651     # arguments:
#     652     derivative = derivatives_all_kwargs.setdefault(
#     653         name,
#     654         # Derivative never needed before:
#     655         partial_derivative(f, name))
#
# File ~\anaconda3\Lib\site-packages\uncertainties\core.py:338, in partial_derivative.<locals>.partial_derivative_of_f(*args, **kwargs)
#     336     shifted_f_minus = f(*args, **args_with_var)
#     337 else:
# --> 338     shifted_f_minus = f(*args_with_var, **kwargs)
#     340 return (shifted_f_plus - shifted_f_minus)/2/step
#
# File ~\anaconda3\Lib\site-packages\lmfit\parameter.py:43, in asteval_with_uncertainties(obj, pars, names, *vals, **kwargs)
#      40     _asteval.symtable[name] = val
#      42 # re-evaluate constraint parameters topropagate uncertainties
# ---> 43 [p._getval() for p in pars.values()]
#      44 return _asteval.eval(obj._expr_ast)
#
# File ~\anaconda3\Lib\site-packages\lmfit\parameter.py:945, in Parameter._getval(self)
#     943     if self._expr_eval is not None and not self._delay_asteval:
#     944         self.value = self._expr_eval(self._expr_ast)
# --> 945         check_ast_errors(self._expr_eval)
#     946 return self._val
#
# File ~\anaconda3\Lib\site-packages\lmfit\parameter.py:27, in check_ast_errors(expr_eval)
#      25 """Check for errors derived from asteval."""
#      26 if len(expr_eval.error) > 0:
# ---> 27     expr_eval.raise_exception(None)
#
# File ~\anaconda3\Lib\site-packages\asteval\asteval.py:249, in Interpreter.raise_exception(self, node, exc, msg, expr, lineno)
#     247 if len(err.msg) == 0:
#     248     err.msg = self.error_msg
# --> 249 raise exc(self.error_msg)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Guardamos el array de frecuencias importante

# %%
# Guardar el array en un archivo de texto
# Guardar el array en un archivo .npy
np.save('./Con_corriente_guardados/Datos_obtenidos/frecuencias_en_1.npy', frecuencias)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Guardar el array en un archivo de texto
#       2 # Guardar el array en un archivo .npy
# ----> 3 np.save('./Con_corriente_guardados/Datos_obtenidos/frecuencias_en_1.npy', frecuencias)
#
# NameError: name 'frecuencias' is not defined

# %% [markdown]
# ## Cuando sea importante extraemos el array de frecuencias

# %%
# Cargar el array desde el archivo de texto
frecuencias = np.load('./Con_corriente_guardados/Datos_obtenidos/frecuencias_en_1.npy')

print("Array cargado desde 'frecuencias_en_1.npy.npy':")
# Out:
# Array cargado desde 'frecuencias_en_1.npy.npy':

# %% [markdown]
# ## Graficamos las frecuencias del 1-8

# %%
# Crear una figura con 6 subplots organizados en 2 filas y 3 columnas
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

# Iterar sobre los subplots y las imágenes
for ax, idx in zip(axes.flat, range(0, 8)):
    frecuencia = frecuencias[:,:,idx]
    im = ax.imshow(frecuencia, cmap='viridis')
    ax.set_title(f'Imagen {idx}')
    ax.axis('off')  # Opcional: desactivar los ejes
    
    # Añadir una barra de color para cada imagen
    cbar = plt.colorbar(im, ax=ax, orientation='vertical')
    cbar.ax.set_ylabel('Intensidad', rotation=270, labelpad=10)
    
fig.delaxes(axes[2,2])  # Elimina el  subplot

plt.savefig('./Con_corriente_guardados/Resultados/frecuenciasCalculadas.png')
plt.show()

# %% [markdown]
# # Calculamos las proyecciones de los campos magnéticos

# %% [markdown]
# ## Hallando los ejes de simetria

# %%
filas = []
for i in range(frecuencias.shape[0]):
    columna = []
    for j in range(frecuencias.shape[1]): 
        campos = []
        for k in range(1,5):
            
            B_NV = abs((frecuencias[i,j,-k] -frecuencias[i,j,k-1]))/(2*28)*10**3 # Esto sale en microtesla
            campos.append(B_NV)
            
        columna.append(np.array(campos))  
    
    filas.append(np.array(columna))
    
proyecciones_campos = np.array(filas)
proyecciones_campos.shape
# Out:
# (128, 128, 4)

# %% [markdown]
# ## Graficamos las 4 proyecciones de campos magneticos

# %%
# Crear una figura con 6 subplots organizados en 2 filas y 3 columnas
fig, axes = plt.subplots(2, 2, figsize=(18, 18))

# Iterar sobre los subplots y las imágenes
for ax, idx in zip(axes.flat, range(0, 4)):
    campo = proyecciones_campos[:,:,idx]
    im = ax.imshow(campo, cmap='viridis')
    microtesla = "\mathrm{\mu T}"
    ax.set_title(fr'$B_{{NV}}\;{idx+1}({microtesla})$',fontsize=30)
    ax.axis('off')  # Opcional: desactivar los ejes
    
    # Añadir una barra de color para cada imagen
    cbar = plt.colorbar(im, ax=ax, orientation='vertical',fraction=0.045)
    cbar.ax.tick_params(labelsize=16)
    cbar.ax.set_ylabel('Intensidad', rotation=270, labelpad=25,fontsize=25)
    
'''
left, right, top, bottom: Definen los márgenes externos de la figura (valores entre 0 y 1, donde 0 es el borde izquierdo/inferior y 1 el borde derecho/superior).
wspace: Controla el espacio horizontal entre los subplots. Un valor menor junta los subplots.
hspace: Controla el espacio vertical entre los subplots. Un valor menor reduce la separación vertical.
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1, wspace=0.1, hspace=0.1)
'''
plt.subplots_adjust(wspace=0.25)

fig.savefig('./Con_corriente_guardados/Resultados/proyecBNV.png')
fig.savefig('./proyecBNV.png')
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\JAAL_\AppData\Local\Temp\ipykernel_48476\2854427138.py:8: SyntaxWarning: invalid escape sequence '\m'
#   microtesla = "\mathrm{\mu T}"

# %% [markdown]
# # Calculamos ahora los 3 campos magneticos en los ejes x,y,z y campo magnetico total

# %%
proyecciones_campos[3,2,0]
# Out:
# 3835.424997813423

# %%
######################################################################################33

### Sistemas de referencia
baseB = np.eye(3)
baseB_ = np.array([[0,-np.sqrt(2/3),-np.sqrt(1/3)],
                   [np.sqrt(2/3),0,-np.sqrt(1/3)],
                   [-np.sqrt(2/3),0,-np.sqrt(1/3)],
                   [0,np.sqrt(2/3),-np.sqrt(1/3)]])



# Definir la matriz de coeficientes A (4 ecuaciones y 3 incógnitas)
A = np.array([[baseB_[0] @ baseB[0].T, baseB_[0] @ baseB[1].T, baseB_[0] @ baseB[2].T],
            [baseB_[1] @ baseB[0].T, baseB_[1] @ baseB[1].T, baseB_[1] @ baseB[2].T],
            [baseB_[2] @ baseB[0].T, baseB_[2] @ baseB[1].T, baseB_[2] @ baseB[2].T],
            [baseB_[3] @ baseB[0].T, baseB_[3]@ baseB[1].T, baseB_[3] @ baseB[2].T]])

# Calcular la pseudoinversa de Moore-Penrose de A
A_pseudo = np.linalg.pinv(A)

filas = []
for i in range(proyecciones_campos.shape[0]):
    columna = []
    for j in range(proyecciones_campos.shape[1]): 
        # Definir el vector de términos independientes b
        b = np.array([proyecciones_campos[i,j,0],
                      proyecciones_campos[i,j,1],
                      proyecciones_campos[i,j,2],
                      proyecciones_campos[i,j,3]])
        
        # solution, residuals, rank, singular_values = np.linalg.lstsq(A, b, rcond=None) # este es a lo directo
        solution = A_pseudo @ b # Resolver el sistema usando la pseudoinversa
        
        Bx = solution[0]
        By = solution[1]
        Bz = solution[2]
        B = (Bx**2 + By**2 + Bz**2)**(1/2)
    
        columna.append(np.array([Bx,By,Bz,B]))

    filas.append(columna)

campos_magneticos = np.array(filas)
campos_magneticos.shape
# Out:
# (128, 128, 4)

# %% [markdown]
# ## Graficamos los campos magneticos

# %%
# Crear una figura con 6 subplots organizados en 2 filas y 3 columnas
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

# Iterar sobre los subplots y las imágenes
for ax, idx in zip(axes.flat, range(0, 4)):
    campo = campos_magneticos[:,:,idx]
    im = ax.imshow(campo, cmap='bwr')
    ax.set_title(f'Imagen {idx}')
    ax.axis('off')  # Opcional: desactivar los ejes
    
    # Añadir una barra de color para cada imagen
    cbar = plt.colorbar(im, ax=ax, orientation='vertical')
    cbar.ax.set_ylabel('Intensidad', rotation=270, labelpad=10)

fig.savefig('./Con_corriente_guardados/Resultados/CamposBcal.png')

# %%
# Guardar el array en un archivo .npy
np.save('./Con_corriente_guardados/Datos_obtenidos/CamposBcal.npy', campos_magneticos)
